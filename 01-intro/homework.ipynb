# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
print("a")
# Out:
# a

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 91 kB/s s eta 0:00:01     |███████████████████             | 25.4 MB 12.6 MB/s eta 0:00:02
# ...
